# %%
import pandas as pd
import time

# %%
data = pd.read_csv("tmp/output_stream.csv")
data.head()
# Out:
#    user_id  total_steps  avg_calories_burned  total_active_minutes  \
# 0      687        22850              3831.47                   482
# 1      374         2912              2100.46                   886
# 2      869         4641              2436.38                   595
# 3      248          431              2969.94                   654
# 4      177        16949              3187.79                   505
#
#    avg_sleep_hours mood_summary  workout_count  is_stressed  is_unhappy  \
# 0              0.3      Neutral              1         True       False
# 1              8.3     Stressed              1        False       False
# 2              1.5        Tired              1         True       False
# 3              2.6      Neutral              1         True       False
# 4              8.8     Stressed              1        False        True
#
#    heart_attack_alert  potential_burnout  weather_impact  \
# 0               False              False           False
# ...

# %%
import google.generativeai as genai 
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
import google.generativeai as genai
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
genai.configure(api_key="AIzaSyAY3XYebUxJhoQaW7cykmv01EQVEEARhMw")

def get_pdf_text(pdf_docs):
    text = " "
    for pdf in pdf_docs:
        pdf_reader = PdfReader(pdf)
        for page in pdf_reader.pages:
            text += page.extract_text()

    return text

# %%
def get_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=1000)
    chunks = text_splitter.split_text(text)
    return chunks

# %%
def get_vector_store(text_chunks):     
    embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

    vector_store = FAISS.from_texts(text_chunks, embedding=embeddings)

    vector_store.save_local("faiss_index")

# %%
def get_conversational_chain():
    prompt_template = """
    Answer the question as detailed as possible from the provided context, make sure to provide all the details,
    if the answer is not in the provided context just say, "answer is not available in the context", don't provide the wrong answer\n\n
    Context:\n {context}?\n
    Question: \n{question}\n

    Answer:
    """
    model = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.3)

    prompt = PromptTemplate(
        template=prompt_template, input_variables=["context", "question"]
    )

    chain = load_qa_chain(model, chain_type="stuff", prompt=prompt)

    return chain

# %%
def user_input(user_question):
    embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

    new_db = FAISS.load_local("faiss_index", embeddings)

    docs = new_db.similarity_search(user_question)

    chain = get_conversational_chain()

    response = chain(
        {"input_documents": docs, "question": user_question}, return_only_outputs=True
    )

    print(response)

# %%
text = get_pdf_text("database/Benefitsneedandimportanceofdailyexercise.pdf")
chunks = get_chunks(text)
get_vector_store(chunks)
user_input("Tell me about fitness")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 text = get_pdf_text("database/Benefitsneedandimportanceofdailyexercise.pdf")
#       2 chunks = get_chunks(text)
#       3 get_vector_store(chunks)
#
# Cell In[11], line 6, in get_pdf_text(pdf_docs)
#       4 text = " "
#       5 for pdf in pdf_docs:
# ----> 6     pdf_reader = PdfReader(pdf)
#       7     for page in pdf_reader.pages:
#       8         text += page.extract_text()
#
# File /mnt/d/Hackathon-National/myenv/lib/python3.12/site-packages/PyPDF2/_reader.py:317, in PdfReader.__init__(self, stream, strict, password)
#     311     logger_warning(
#     312         "PdfReader stream/file object is not in binary mode. "
#     313         "It may not be read correctly.",
#     314         __name__,
#     315     )
#     316 if isinstance(stream, (str, Path)):
# ...

# %%
genai.configure(api_key="AIzaSyAY3XYebUxJhoQaW7cykmv01EQVEEARhMw")

model = genai.GenerativeModel("gemini-1.5-flash")
# response = model.generate_content("How does AI work?")
# print(response.text)

# %%
responses = []

for _, row in data.head(20).iterrows():
    prompt = (
        # f"These are insights from a fitness tracker app and based on this information i want best advices , suggestions regarding this information only and 
        # if response is not available then respond with None.The responses could be advices , suggestions , best practices and also appreciation if the user is doing 
        # good\n"
        f"User Insights:\n"
        f"User ID: {row['user_id']}\n"
        f"Total Steps: {row['total_steps']}\n"
        f"Average Calories Burned: {row['avg_calories_burned']}\n"
        f"Total Active Minutes: {row['total_active_minutes']}\n"
        f"Average Sleep Hours: {row['avg_sleep_hours']}\n"
        f"Mood Summary: {row['mood_summary']}\n"
        f"Workout Count: {row['workout_count']}\n"
        f"Stressed: {'Yes' if row['is_stressed'] else 'No'}\n"
        f"Unhappy: {'Yes' if row['is_unhappy'] else 'No'}\n"
        f"Heart Attack Alert : {'Yes' if row['heart_attack_alert'] else 'No'}"
        f"Potential Burnout : {'Yes' if row['potential_burnout'] else 'No'}"
        f"Weather Impact on steps : {'Yes' if row['weather_impact'] else 'No'}"
        f"Risk of heart attack due to lack of sleep : {'Yes' if row['risk_of_heart_attack'] else 'No'}"
        f"Overall fitness score : {'Yes' if row['overall_fitness_score'] else 'No'}"
        f"These are insights from a fitness tracker app.Based on these insights, suggest ways to improve this user's fitness and mental health. Keep response short and concise.Use user id at start of response"
    )

    response = model.generate_content(prompt)
    responses.append(response.text)

    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[6], line 27
#       5 prompt = (
#       6     # f"These are insights from a fitness tracker app and based on this information i want best advices , suggestions regarding this information only and
#       7     # if response is not available then respond with None.The responses could be advices , suggestions , best practices and also appreciation if the user is doing
#    (...)
#      24     f"These are insights from a fitness tracker app.Based on these insights, suggest ways to improve this user's fitness and mental health. Keep response short and concise.Use user id at start of response"
#      25 )
#      26 # Generate response using the Gemini model
# ---> 27 response = model.generate_content(prompt)
#      28 # Store the response text
#      29 responses.append(response.text)
#
# ...

# %%
len(responses)
# Out:
# 15

# %%
df = data.head(15)
df
# Out:
#     user_id  total_steps  avg_calories_burned  total_active_minutes  \
# 0       687        22850              3831.47                   482
# 1       374         2912              2100.46                   886
# 2       869         4641              2436.38                   595
# 3       248          431              2969.94                   654
# 4       177        16949              3187.79                   505
# 5       678         5632              3282.66                   578
# 6       192         3364              3998.92                   718
# 7       882         9556              3581.64                   463
# 8       633         2992              2759.26                   945
# 9       670        29800              1812.50                  1032
# 10      994         3582              1868.32                   754
# 11      644          530              2448.33                   714
# 12      182        22274              1951.05                   909
# ...

# %%
df['Recommendations'] = responses
# Out:
# /tmp/ipykernel_205460/3209481137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Recommendations'] = responses

# %%
df.head()
# Out:
#    user_id  total_steps  avg_calories_burned  total_active_minutes  \
# 0      687        22850              3831.47                   482
# 1      374         2912              2100.46                   886
# 2      869         4641              2436.38                   595
# 3      248          431              2969.94                   654
# 4      177        16949              3187.79                   505
#
#    avg_sleep_hours mood_summary  workout_count  is_stressed  is_unhappy  \
# 0              0.3      Neutral              1         True       False
# 1              8.3     Stressed              1        False       False
# 2              1.5        Tired              1         True       False
# 3              2.6      Neutral              1         True       False
# 4              8.8     Stressed              1        False        True
#
#    heart_attack_alert  potential_burnout  weather_impact  \
# 0               False              False           False
# ...

# %%
df.to_csv('out.csv')
